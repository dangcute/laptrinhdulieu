# %%
a=4
type(a)
# Out:
# int

# %%
a=2.1
type(a)
# Out:
# float

# %%
a=1.5+0.5j
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 1.5

# %%
test=(3>4)
type(test)
# Out:
# bool

# %%
test
# Out:
# False

# %%
7/2
# Out:
# 3.5

# %%
int(2.3)
# Out:
# 2
